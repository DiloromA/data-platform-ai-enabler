# %% [markdown]
# # AI / BI Payoff
#
# This notebook demonstrates the business payoff of the trusted semantic layer.

# %%
# %sql
SELECT campaign_name,
       total_impressions,
       total_clicks,
       total_spend,
       total_revenue,
       click_through_rate,
       roas,
       avg_view_duration_seconds
FROM adtech_demo.adtech_platform.vw_campaign_metrics
ORDER BY total_revenue DESC
LIMIT 10;

# %% [markdown]
# ## Discussion
# - showcase a BI dashboard built on `vw_campaign_metrics`
# - explain how trusted metrics enable self-serve analytics
# - connect the result to better campaign decisions and media ROI
