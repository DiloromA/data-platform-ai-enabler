# %% [markdown]
# # Lineage and Trust
#
# This notebook connects the source tables to derived business metrics and illustrates trust.

# %% [markdown]
# ## Lineage views
#
# The `vw_lineage_summary` view was created in the previous notebook (03_data_quality). This cell displays the lineage relationships.

# %%
# %sql
SELECT * FROM adtech_demo.adtech_platform.vw_lineage_summary;

# %% [markdown]
# ## What lineage shows
# - which source tables contribute to key metrics
# - how campaign spend, impressions, clicks, and revenue are combined
# - why traceability matters for dashboards and AI models
